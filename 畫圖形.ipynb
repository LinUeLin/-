# %%
import numpy as np
import matplotlib.pyplot as pt
N=50
x=np.random.rand(N)
y=np.random.rand(N)
pt.scatter(x,y)
pt.show()

# %%
#畫出sin wave
import numpy
import matplotlib.pyplot as pt
x=np.arange(0,360)
y=np.sin(x*np.pi/180.0)
pt.xlim(0,360)
pt.ylim(-1.2,1.2)
pt.title("sin function")
pt.plot(x,y)
pt.show()

# %%
#畫出sin & cos wave
import numpy
import matplotlib.pyplot as pt
x=np.arange(0,360)
y=np.sin(x*np.pi/180.0)
z=np.cos(x*np.pi/180.0)
pt.xlim(0,360)
pt.ylim(-1.2,1.2)
pt.title("sin cos function")
pt.plot(x,y,color = "blue")
pt.plot(x,z,color = "red")
pt.show()

# %%
import numpy as ng
import matplotlib.pyplot as pt
x=[1,2,3,4]
pt.plot(x)
pt.plot(x,"--")
pt.show()

# %%
import numpy as ng
import matplotlib.pyplot as pt
x=[1,2,3,4]
y=[3,7,2,6]
pt.bar(x,y,label="bar")
pt.legend()
pt.show()
